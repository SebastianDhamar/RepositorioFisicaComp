# %% [markdown]
# <h1 align="center">Física Computacional.</h1>
# <h1 align="center">Semestre 2027-1</h1>
#
# <h2>Sergio A. Alcalá Corona </h2>
#
# ---
# ### Rodrigo Vega Vilchis
# ### Joel Gómez Uribe
# ---
# ### Alumno: Monroy García Sebástian Dhamar
# ---

# %% [markdown]
# <h1 align="center">Programación para la física computacional</h1>
#
# ## Práctica 1.  Programación básica para la física
#
# ---

# %% [markdown]
# ### **EJERCICIOS**:
#
# $\;$
#
# ### **1. Coordenadas polares y cartesianas:**
# #### Supongamos que se nos da (es decir, el usuario introduce) la posición de un punto en un espacio bidimensional:
#
# #### **a)** Si el punto se especifica  en coordenadas polares $r$,$\theta$. Escribe un programa (en `python` sin usar la biblioteca `numpy`) que calcule e imprima la conversión a coordenadas cartesianas $x$, $y$.

# %%
import math as mt

r = float(input("Introduce el valor de r = "))
theta = float(input("Introduce, en grados, el valor de Theta= "))
theta = mt.radians(theta)


x = r*(mt.cos(theta))
y = r*(mt.sin(theta))

x = round(x,4)
y = round(y,4)

x = str(x)
y =str(y)

print("Tus coordenadas son x: " + x)
print("y: " + y)
# Out:
# Introduce el valor de r =  5
# Introduce, en grados, el valor de Theta=  90
# Tus coordenadas son x: 0.0
# y: 5.0

# %% [markdown]
# #### **b)** Si el punto se especifica en coordenadas cartesianas $x$, $y$. Escribe un programa (en `python` sin usar `numpy`) que calcule e imprima la conversión a coordenadas polares $r$,$\theta$.

# %%
import math as mt

x = float(input("Introduce el valor de la coordenada x = "))
y = float(input("Introduce el valor de la coordenada y = "))

r = mt.sqrt((x**2)+(y**2))

if x == 0:
    t = mt.atan2(y,x)
else:
    t = mt.atan(y/x)

t = mt.degrees(t)

r = round(r,5)
t = round(t,5)

r = str(r)
t = str(t)

print("Tus coordenadas polares son r = " + r + ", y theta = " + t + "°")
# Out:
# Introduce el valor de la coordenada x =  0
# Introduce el valor de la coordenada y =  1
# Tus coordenadas polares son r = 1.0, y theta = 90.0°

# %% [markdown]
# ### **2. Caída de una pelota desde una torre:**
# #### Se deja caer una pelota desde una torre de altura $h$. Tiene velocidad inicial cero y acelera hacia abajo con la gravedad.
#
# Escribe un programa que le pida al usuario que ingrese la altura en metros de la torre y luego calcule e imprima el tiempo en segundos hasta que la pelota toque el suelo (ignora la resistencia del aire).
#
# Después, usa tu programa para calcular el tiempo de una pelota lanzada desde una torre de $100m$ de altura.\\

# %%
import math as mt

g = float(9.81)
h = float(input("Introduce la altura a la que se suelta tu pelota en metros (omite unidades): "))

t = mt.sqrt(2*h/g)

h = str(h)
t = str(t)

print("Si tu pelota se suelta a " + h + "m de altura y cae por la gravedad, tardará " + t + " segundos en tocar el suelo")
# Out:
# Introduce la altura a la que se suelta tu pelota en metros (omite unidades):  10
# Si tu pelota se suelta a 10.0m de altura y cae por la gravedad, tardará 1.4278431229270645 segundos en tocar el suelo

# %%
import math as mt

g = float(9.81)
#h = float(input("Introduce la altura a la que se suelta tu pelota en metros (omite unidades): "))
h = 100

t = mt.sqrt(2*h/g)

h = str(h)
t = str(t)

print("Si tu pelota se suelta a " + h + "m de altura y cae por la gravedad, tardará " + t + " segundos en tocar el suelo")
# Out:
# Si tu pelota se suelta a 100m de altura y cae por la gravedad, tardará 4.515236409857309 segundos en tocar el suelo

# %% [markdown]
# ### **3. Relatividad especial:**
# #### Una nave espacial viaja desde la Tierra en línea recta a una velocidad relativista $v$ a otro planeta a $x$ años luz de distancia.
#
# #### Escribe un programa que le pida al usuario el valor de $x$ y la velocidad $v$ como una fracción de la velocidad de la luz $c$, y que imprima el tiempo en años que tarda la nave espacial en llegar a su destino
#
# #### **(a)** en el marco de reposo de un observador en la Tierra y

# %%
import math as mt

x = float(input("Introduce la distancia en años luz del planeta lejano: "))
B = float(input("Introduce la velocidad de tu nave como fracción de la velocidad de la luz, omite c: "))

#Quiero c en año luz/año, pero esto debe ser 1, entonces v = Bc = B

t = x/(B*1)

# L = 1/(mt.sqrt(1-(B)**2))
# tau = t/L

B = str(B)
x = str(x)
t = str(t)
# tau = str(tau)

print("Segun un observador en la tierra, tu nave que viaja a " + B + "c, llegará al planeta a " + x + " años luz en " + t + " años")
# print("Segun el viajero en la nave, tu nave que viaja a " + B + "c, llegará al planeta a " + x + " años luz en " + tau + " años")
# Out:
# Introduce la distancia en años luz del planeta lejano:  17
# Introduce la velocidad de tu nave como fracción de la velocidad de la luz, omite c:  0.5
# Segun un observador en la tierra, tu nave que viaja a 0.5c, llegará al planeta a 17.0 años luz en 34.0 años

# %% [markdown]
# #### **(b)** como lo percibiría un pasajero a bordo de la nave.

# %%
import math as mt

x = float(input("Introduce la distancia en años luz del planeta lejano: "))
B = float(input("Introduce la velocidad de tu nave como fracción de la velocidad de la luz, omite c: "))

#Quiero c en año luz/año, pero esto debe ser 1, entonces v = Bc = B

t = x/(B*1)

L = 1/(mt.sqrt(1-(B)**2))
tau = t/L

B = str(B)
x = str(x)
t = str(t)
tau = str(tau)

# print("Segun un observador en la tierra, tu nave que viaja a " + B + "c, llegará al planeta a " + x + " años luz en " + t + " años")
print("Segun el viajero en la nave, tu nave que viaja a " + B + "c, llegará al planeta a " + x + " años luz en " + tau + " años")
# Out:
# Introduce la distancia en años luz del planeta lejano:  17
# Introduce la velocidad de tu nave como fracción de la velocidad de la luz, omite c:  0.5
# Segun el viajero en la nave, tu nave que viaja a 0.5c, llegará al planeta a 17.0 años luz en 29.44486372867091 años

# %% [markdown]
# #### Usa tu programa para calcular las respuestas para un planeta a 10 años luz de distancia con $v = 0.99c$

# %%
import math as mt

# x = float(input("Introduce la distancia en años luz del planeta lejano: "))
x = 10
# B = float(input("Introduce la velocidad de tu nave como fracción de la velocidad de la luz, omite c: "))
B = 0.99
#Quiero c en año luz/año, pero esto debe ser 1, entonces v = Bc = B

t = x/(B*1)

L = 1/(mt.sqrt(1-(B)**2))
tau = t/L

B = str(B)
x = str(x)
t = str(t)
tau = str(tau)

print("Segun un observador en la tierra, tu nave que viaja a " + B + "c, llegará al planeta a " + x + " años luz en " + t + " años")
print("Segun el viajero en la nave, tu nave que viaja a " + B + "c, llegará al planeta a " + x + " años luz en " + tau + " años")
# Out:
# Segun un observador en la tierra, tu nave que viaja a 0.99c, llegará al planeta a 10 años luz en 10.1010101010101 años
# Segun el viajero en la nave, tu nave que viaja a 0.99c, llegará al planeta a 10 años luz en 1.424922826228878 años

# %%
import math as mt

x = float(input("Introduce la distancia en años luz del planeta lejano: "))
B = float(input("Introduce la velocidad de tu nave como fracción de la velocidad de la luz, omite c: "))
#Quiero c en año luz/año, pero esto debe ser 1, entonces v = Bc = B

t = x/(B*1)

L = 1/(mt.sqrt(1-(B)**2))
tau = t/L

B = str(B)
x = str(x)
t = str(t)
tau = str(tau)

print("Segun un observador en la tierra, tu nave que viaja a " + B + "c, llegará al planeta a " + x + " años luz en " + t + " años")
print("Segun el viajero en la nave, tu nave que viaja a " + B + "c, llegará al planeta a " + x + " años luz en " + tau + " años")
# Out:
# Introduce la distancia en años luz del planeta lejano:  10
# Introduce la velocidad de tu nave como fracción de la velocidad de la luz, omite c:  0.99
# Segun un observador en la tierra, tu nave que viaja a 0.99c, llegará al planeta a 10.0 años luz en 10.1010101010101 años
# Segun el viajero en la nave, tu nave que viaja a 0.99c, llegará al planeta a 10.0 años luz en 1.424922826228878 años

# %% [markdown]
# ### **4. Paso de potencial cuántico.**
# #### Un conocido problema de mecánica cuántica involucra una partícula de masa $m$ que encuentra un paso de potencial unidimensional, como este:
#
# <center><img src="img/qstep2.png" width="50%" class="center"/></center>
#
# #### La partícula con energía cinética inicial $E$ y vector de onda $k_1=\sqrt{2mE}/\hbar$ entra por la izquierda y encuentra un salto repentino en la energía potencial de altura $V$ en la posición $x=0$. Resolviendo la ecuación de Schrödinger, se puede demostrar que cuando $E>V$ la partícula puede
#
# #### (a) **pasar el escalón**, en cuyo caso tiene una energía cinética menor a $E-V$ en el otro lado y un vector de onda correspondientemente menor a $k_2=\sqrt{2m(E-V)}/\hbar$, \; o bien (b) **reflejarse**, manteniendo toda su energía cinética y un vector de onda sin cambios, pero moviéndose en la dirección opuesta. Las probabilidades $T$ y $R$ de transmisión y reflexión están dadas por:
#
# <h3 align="center">$T = {4k_1k_2\over(k_1+k_2)^2}\,,\qquad$
# $R = \biggl( {k_1-k_2\over k_1+k_2} \biggr)^2.$</h3>
#
# #### Supongamos que tenemos una partícula con una masa igual a la masa del electrón. $m=9.11\times10^{-31}\,$kg y energía de $10\,$eV, al encontrar un escalón de potencial de altura $9\,$eV. Escribe un programa en \texttt{Python} para calcular e imprimir las probabilidades de transmisión y reflexión utilizando las fórmulas anteriores.

# %%
import math as mt

m = 9.11*(10**(-31))
E = 10
V = 9
h = 6.63*(10**(-34))
hb = h/(2*mt.pi)


k1 = (mt.sqrt(2*m*E))/hb
k2 = (mt.sqrt(2*m*(E-V)))/hb

T = (4*k1*k2)/((k1+k2)**2)
R = ((k1-k2)/(k1+k2))**2

# One = T + R

T = str(T)
R = str(R)


print("La posibilidad de transmisión es " + T)
print("La posibilidad de reflectores es " + R)
# print(One)
# Out:
# La posibilidad de transmisión es 0.7301261363877616
# La posibilidad de reflectores es 0.26987386361223836
